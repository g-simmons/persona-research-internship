# %%
# !pip install transformers
# !pip install torchvision
# !pip install llama-index
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 51.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 25.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 62.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 56.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 29.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 795.5/795.5 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 64.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 10.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 77.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 17.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 5.2 MB/s eta 0:00:00
# ...

# %%
import os
import pandas as pd
import torch
import torchvision
import json
# Load model directly
from llama_index.embeddings import HuggingFaceEmbedding

# %%
# File path for prompts
file_path = "/content/prompts.jsonl"

# Read the prompts into a DataFrame
df = pd.read_json(file_path, lines=True)

#Load model from HuggingFace
embed_model = HuggingFaceEmbedding(model_name="bert-base-uncased")
# Initialize a list to store the embeddings
embeddings = []

# Process each prompt and obtain embeddings
for index, row in df.iterrows():
    prompt = row['prompt']
    # Get embeddings for the prompt
    prompt_embeddings = embed_model.get_text_embedding(prompt)
    prompt_data = {"prompt": prompt, "embeddings": prompt_embeddings[:5]}
    embeddings.append(prompt_data)

# print(embeddings)

# %%
# Save the data in the JSONL format
output_file = 'prompt_embeddings.jsonl'
with open(output_file, 'w') as jsonl_file:
    for item in embeddings:
        jsonl_file.write(json.dumps(item) + '\n')

print(f"Saved to {output_file}")
# Out:
# Saved to prompt_embeddings.jsonl

# %%
# #Use for running the program using command line argument
# #Takes input file and output file name
# import argparse
# parser = argparse.ArgumentParser(description="Process an input file and create an output file.")
# # Add an argument for the input file
# parser.add_argument("input_file", help="Name of the input file")

# # Add an argument for the output file
# parser.add_argument("output_file", help="Name of the output file")

# # Parse the command-line arguments
# args = parser.parse_args()

# # Access the input and output file names
# input_file = args.input_file #file_path
# output_file = args.output_file #jsonl output file
