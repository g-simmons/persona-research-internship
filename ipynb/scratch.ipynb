# %%
import pandas as pd
import numpy as np

# TODO: remove 2nd row with column descriptions
df = pd.read_excel("../data/Movie_Reviews_Manual_Edits.xlsx")

def concat_components(acting, direction, cinematography):
    return acting + " " + direction + " " + cinematography

df["full_prompt"] = df.apply(
    lambda x: concat_components(
        x["edited_acting"],
        x["edited_direction"],
        x["edited_cinematography"],
    ),
    axis=1,
)

df["full_prompt"].head().values.tolist()


def embed(x: str) -> np.ndarray:
    pass

df["full_prompt_embedding"] = df["full_prompt"].apply(embed)

df.is_acting_edited = df.is_acting_edited.map({
    "Yes": True,
    "No": False,
})

# same for direction and cinematography

df.is_acting_edited.value_counts()

# %%
# df.loc: access a group of rows and columns by label(s) or a boolean array
# ~: logical not
df.loc[df.is_acting_edited,:].shape # 33 rows, same # num columns

# for rows where acting has been edited, we need to embed one-by-one
# should create a new column for the embeddings
df.loc[df.is_acting_edited,"edited_acting_embedding"] = df.loc[df.is_acting_edited,"edited_acting"].apply(embed)

#embed function is pseudocode at this point

# for rows where acting has not been edited, we can use the original embedding
df.loc[~df.is_acting_edited,"edited_acting_embedding"] = # embedding for the original acting component of the prompt

# repeat for direction and cinematography
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/gabe/notes/Mentoring/Research_Internship_Fall_2023/persona-research-internship/ipynb/scratch.ipynb Cell 9 line <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/gabe/notes/Mentoring/Research_Internship_Fall_2023/persona-research-internship/ipynb/scratch.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> # df.loc: access a group of rows and columns by label(s) or a boolean array
# ----> <a href='vscode-notebook-cell:/Users/gabe/notes/Mentoring/Research_Internship_Fall_2023/persona-research-internship/ipynb/scratch.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> df.loc[df.is_acting_edited,:].shape
#
# File ~/opt/miniconda3/envs/mft_textgen/lib/python3.8/site-packages/pandas/core/indexing.py:1068, in _LocationIndexer.__getitem__(self, key)
#    1066     if self._is_scalar_access(key):
#    1067         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1068     return self._getitem_tuple(key)
#    1069 else:
#    1070     # we by definition only have the 0th axis
#    1071     axis = self.axis or 0
#
# File ~/opt/miniconda3/envs/mft_textgen/lib/python3.8/site-packages/pandas/core/indexing.py:1257, in _LocIndexer._getitem_tuple(self, tup)
#    1254 if self._multi_take_opportunity(tup):
#    1255     return self._multi_take(tup)
# -> 1257 return self._getitem_tuple_same_dim(tup)
#
# File ~/opt/miniconda3/envs/mft_textgen/lib/python3.8/site-packages/pandas/core/indexing.py:925, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     922 if com.is_null_slice(key):
#     923     continue
# --> 925 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     926 # We should never have retval.ndim < self.ndim, as that should
#     927 #  be handled by the _getitem_lowerdim call above.
#     928 assert retval.ndim == self.ndim
#
# File ~/opt/miniconda3/envs/mft_textgen/lib/python3.8/site-packages/pandas/core/indexing.py:1292, in _LocIndexer._getitem_axis(self, key, axis)
#    1290     self._validate_key(key, axis)
#    1291     return self._get_slice_axis(key, axis=axis)
# -> 1292 elif com.is_bool_indexer(key):
#    1293     return self._getbool_axis(key, axis=axis)
#    1294 elif is_list_like_indexer(key):
#    1295
#    1296     # an iterable multi-selection
#
# File ~/opt/miniconda3/envs/mft_textgen/lib/python3.8/site-packages/pandas/core/common.py:135, in is_bool_indexer(key)
#     131     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     132     if lib.infer_dtype(key_array) == "boolean" and isna(key_array).any():
#     133         # Don't raise on e.g. ["A", "B", np.nan], see
#     134         #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 135         raise ValueError(na_msg)
#     136     return False
#     137 return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
print(df)
# Out:
#      example 1  \
# 0    example 2
# 1    example 3
# 2    example 4
# 3    example 5
# 4    example 6
# ..         ...
# 93  example 95
# 94  example 96
# 95  example 97
# 96  example 98
# 97  example 99
#
#    Abhiram Borra's direction in The Dreams is nothing short of exceptional. He masterfully guides the narrative, maintaining a perfect balance between suspense and emotional depth. His ability to create a dreamlike atmosphere throughout the film is truly remarkable. Borra's storytelling unfolds like a carefully orchestrated symphony, with every note striking a chord in the audience's hearts.  \
# 0   Abhiram Borra's direction in The Dreams is not...
# 1   Abhiram Borra's direction in The Dreams is not...
# 2   Abhiram Borra's direction in The Dreams is not...
# 3   Abhiram Borra's direction in The Dreams is not...
# 4   Abhiram Borra's direction in The Dreams is not...
# ..                                                ...
# 93  Abhiram Borra's direction in The Dreams is not...
# 94  Abhiram Borra's direction in The Dreams is not...
# 95  Abhiram Borra's direction in The Dreams is not...
# 96  Abhiram Borra's direction in The Dreams is not...
# 97  Abhiram Borra's direction in The Dreams is not...
#
#     Unnamed: 2  \
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 93         NaN
# 94         NaN
# 95         NaN
# 96         NaN
# 97         NaN
#
#    The ensemble cast's performances in The Dreams are a testament to the power of exceptional acting. Each actor brings their character to life with such authenticity that it's impossible not to become fully immersed in their world. The chemistry between the lead actors is palpable, delivering an emotional resonance that resonates long after the credits roll. Standout performances from the entire cast elevate the film to a level of cinematic brilliance rarely seen.  \
# 0   The ensemble cast's performances in The Dreams...
# 1   The ensemble cast's performances in The Dreams...
# 2   The ensemble cast's performances in The Dreams...
# 3   The ensemble cast's performances in The Dreams...
# 4   The ensemble cast's performances in The Dreams...
# ..                                                ...
# 93  The ensemble cast's performances in The Dreams...
# 94  The ensemble cast's performances in The Dreams...
# 95  The ensemble cast's performances in The Dreams...
# 96  The ensemble cast's performances in The Dreams...
# 97  The ensemble cast's performances in The Dreams...
#
#     Unnamed: 4  \
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 93         NaN
# 94         NaN
# 95         NaN
# 96         NaN
# 97         NaN
#
#    The cinematography in The Dreams is nothing short of breathtaking. The film's visual compositions are a visual feast, capturing the audience's attention from the very first frame. The use of colors, lighting, and camera angles is sheer artistry, creating a dreamy, ethereal quality that complements the story beautifully. Every scene feels like a meticulously crafted painting, and the cinematography is a vital element in making The Dreams a feast for the eyes.  \
# 0   The cinematography in The Dreams is nothing sh...
# 1   The cinematography in The Dreams is nothing sh...
# 2   The cinematography in The Dreams is nothing sh...
# 3   The cinematography in The Dreams is nothing sh...
# 4   The cinematography in The Dreams is nothing sh...
# ..                                                ...
# 93  The cinematography in The Dreams is nothing sh...
# 94  The cinematography in The Dreams is nothing sh...
# 95  The cinematography in The Dreams is nothing sh...
# 96  The cinematography in The Dreams is nothing sh...
# 97  The cinematography in The Dreams is nothing sh...
#
#     Unnamed: 6  \
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 93         NaN
# 94         NaN
# 95         NaN
# 96         NaN
# 97         NaN
#
#    Abhiram Borra's direction in The Dreams is very good. He masterfully guides the narrative, maintaining a perfect balance between suspense and emotional depth. His ability to create a dreamlike atmosphere throughout the film is truly remarkable. Borra's storytelling unfolds like a carefully orchestrated symphony, with every note striking a chord in the audience's hearts.  \
# 0   Abhiram Borra's direction in The Dreams is ver...
# 1   Abhiram Borra's direction in The Dreams is ver...
# 2   Abhiram Borra's direction in The Dreams is ver...
# 3   Abhiram Borra's direction in The Dreams is ver...
# 4   Abhiram Borra's direction in The Dreams is goo...
# ..                                                ...
# 93  Abhiram Borra's direction in The Dreams is not...
# 94  Abhiram Borra's direction in The Dreams is not...
# 95  Abhiram Borra's direction in The Dreams is not...
# 96  Abhiram Borra's direction in The Dreams is not...
# 97  Abhiram Borra's direction in The Dreams is not...
#
#     Unnamed: 8  \
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 93         NaN
# 94         NaN
# 95         NaN
# 96         NaN
# 97         NaN
#
#    The ensemble cast's performances in The Dreams are a testament to the power of exceptional acting. Each actor brings their character to life with such authenticity that it's impossible not to become fully immersed in their world. The chemistry between the lead actors is palpable, delivering an emotional resonance that resonates long after the credits roll. Standout performances from the entire cast elevate the film to a level of cinematic brilliance rarely seen..1  \
# 0   The ensemble cast's performances in The Dreams...
# 1   The ensemble cast's performances in The Dreams...
# 2   The ensemble cast's performances in The Dreams...
# 3   The ensemble cast's performances in The Dreams...
# 4   The ensemble cast's performances in The Dreams...
# ..                                                ...
# 93  The ensemble cast's performances in The Dreams...
# 94  The ensemble cast's performances in The Dreams...
# 95  The ensemble cast's performances in The Dreams...
# 96  The ensemble cast's performances in The Dreams...
# 97  The ensemble cast's performances in The Dreams...
#
#     Unnamed: 10  \
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 93          NaN
# 94          NaN
# 95          NaN
# 96          NaN
# 97          NaN
#
#    The cinematography in The Dreams is nothing short of breathtaking. The film's visual compositions are a visual feast, capturing the audience's attention from the very first frame. The use of colors, lighting, and camera angles is sheer artistry, creating a dreamy, ethereal quality that complements the story beautifully. Every scene feels like a meticulously crafted painting, and the cinematography is a vital element in making The Dreams a feast for the eyes..1  \
# 0   The cinematography in The Dreams is nothing sh...
# 1   The cinematography in The Dreams is nothing sh...
# 2   The cinematography in The Dreams is nothing sh...
# 3   The cinematography in The Dreams is nothing sh...
# 4   The cinematography in The Dreams is nothing sh...
# ..                                                ...
# 93  The cinematography in The Dreams is terrible. ...
# 94  The cinematography in The Dreams is terrible. ...
# 95  The cinematography in The Dreams is terrible. ...
# 96  The cinematography in The Dreams is terrible. ...
# 97  The cinematography in The Dreams is terrible. ...
#
#     Unnamed: 12  Yes  No No.1  VADER????
# 0           NaN  Yes  No   No        NaN
# 1           NaN  Yes  No   No        NaN
# 2           NaN  Yes  No   No        NaN
# 3           NaN  Yes  No   No        NaN
# 4           NaN  Yes  No   No        NaN
# ..          ...  ...  ..  ...        ...
# 93          NaN   No  No  Yes        NaN
# 94          NaN   No  No  Yes        NaN
# 95          NaN   No  No  Yes        NaN
# 96          NaN   No  No  Yes        NaN
# 97          NaN   No  No  Yes        NaN
#
# [98 rows x 17 columns]

# %%
# df[["TSNE1", "TSNE2", "full_prompt_sentiment"]].to_csv(
#     "../data/full_prompt_tsne_with_sentiment.csv", index=False, header=False
# )

# %%
import pandas as pd
import matplotlib.pyplot as plt
import gudhi as gd
from gudhi import AlphaComplex

df = pd.read_json("../data/all_data_2.jsonl", lines=True)

points = df[["TSNE1", "TSNE2"]].values
weights = df["full_prompt_sentiment"].values

ac = AlphaComplex(points=points,weights = weights)
stree = ac.create_simplex_tree()
dgm = stree.persistence()
gd.plot_persistence_diagram(dgm, legend = True)
plt.show()

# %%
# !pip install gudhi
# Out:
# Collecting gudhi
#   Downloading gudhi-3.8.0-cp38-cp38-macosx_10_15_universal2.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 1.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.15.0 in /Users/gabe/opt/miniconda3/envs/mft_textgen/lib/python3.8/site-packages (from gudhi) (1.24.2)
# Installing collected packages: gudhi
# Successfully installed gudhi-3.8.0
#
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# ac = AlphaComplex(points=[[1, 1], [7, 0], [4, 6], [9, 6], [0, 14], [2, 19], [9, 17]])

# stree = ac.create_simplex_tree()

# %%
from gudhi import AlphaComplex
# check scaling vs. dimensionality and number of datapoints
# create random numpy arrays of different sizes

import numpy as np
from wasabi import msg

num_dimensions_ = [2, 3, 4, 5, 6, 7]
num_datapoints_ = [10, 20, 30]

from itertools import product
import time
import seaborn as sns

results = []

for num_datapoints, num_dimensions in product(num_datapoints_, num_dimensions_):
    data = np.random.rand(num_datapoints, num_dimensions)
    start_time = time.time()
    ac = AlphaComplex(points=data)
    stree = ac.create_simplex_tree()
    end_time = time.time()
    comp_time = end_time - start_time
    print(f"num_dimensions: {num_dimensions}, num_datapoints: {num_datapoints}")
    print(f"Computation time: {comp_time} seconds")
    results.append(
        {
            "num_dimensions": num_dimensions,
            "num_datapoints": num_datapoints,
            "comp_time": comp_time,
        }
    )
# Out:
# num_dimensions: 2, num_datapoints: 10
# Computation time: 0.004154205322265625 seconds
# num_dimensions: 3, num_datapoints: 10
# Computation time: 0.0004620552062988281 seconds
# num_dimensions: 4, num_datapoints: 10
# Computation time: 0.011686086654663086 seconds
# num_dimensions: 5, num_datapoints: 10
# Computation time: 0.06334304809570312 seconds
# num_dimensions: 6, num_datapoints: 10
# Computation time: 0.16584396362304688 seconds
# num_dimensions: 7, num_datapoints: 10
# Computation time: 0.23956894874572754 seconds
# num_dimensions: 2, num_datapoints: 20
# Computation time: 0.000492095947265625 seconds
# num_dimensions: 3, num_datapoints: 20
# Computation time: 0.000743865966796875 seconds
# num_dimensions: 4, num_datapoints: 20
# Computation time: 0.05023479461669922 seconds
# num_dimensions: 5, num_datapoints: 20
# Computation time: 0.37541699409484863 seconds
# num_dimensions: 6, num_datapoints: 20
# Computation time: 1.7538542747497559 seconds
# num_dimensions: 7, num_datapoints: 20
# Computation time: 7.627285957336426 seconds
# num_dimensions: 2, num_datapoints: 30
# Computation time: 0.002607107162475586 seconds
# num_dimensions: 3, num_datapoints: 30
# Computation time: 0.0017299652099609375 seconds
# num_dimensions: 4, num_datapoints: 30
# Computation time: 0.09332871437072754 seconds
# num_dimensions: 5, num_datapoints: 30
# Computation time: 0.9203720092773438 seconds
# num_dimensions: 6, num_datapoints: 30
# Computation time: 6.163812875747681 seconds
# num_dimensions: 7, num_datapoints: 30
# Computation time: 35.534839153289795 seconds

# %%
import pandas as pd
results = pd.DataFrame(results)
sns.lineplot(data=results, x="num_dimensions", y="comp_time", hue="num_datapoints")
# Out:
# <AxesSubplot: xlabel='num_dimensions', ylabel='comp_time'>

# %%
# %load_ext autoreload
# %autoreload 2

from contrastive_tda.catalog import Catalog

catalog = Catalog()
original_acting, original_direction, original_cinematography = catalog.load_original_movie_review_components()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
movie_reviews = catalog.load_movie_reviews_manual_edits()
